# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Modelo con datos simulados
# * y = a + b *x
# * x: 100 valores con una media de 5 y una desviacion de 3 N(5,3)
# * Ye (y estimada): una intersección al origen en 5 con una pendiente de 1.9 y una pendiente de error = 5+1.9*x+e
# * e: estará distribuida según una normal de media 0 y una desviacion de 0.8 N(0,4)

# %%
## 100 datos con una media de 5 y una desviacion de 3 N(5,3)
n=100
x=5+3*np.random.randn(n)
plt.hist(x)
# Out:
# (array([ 2.,  2.,  7., 15., 19., 24., 14.,  9.,  6.,  2.]),
#  array([-3.41422872, -1.8611047 , -0.30798068,  1.24514334,  2.79826736,
#          4.35139138,  5.90451539,  7.45763941,  9.01076343, 10.56388745,
#         12.11701147]),
#  <BarContainer object of 10 artists>)

# %%
##creamos y, segunda variable que sera respecto de x, con una media de 5, y una desviacion de 3
## y es nuestra prediccion
y=5+2*x
plt.plot(x,y, "ro")

# %%
## creamos la pendiente de error con una media de 0 y una desviacion de 1
e=0+1*np.random.randn(n)
## creamos una nueva y con porcentage de error, simulará los datos reales
y_act=x+e

# %%
## graficamos
plt.plot(x, y_act, "ro")

# %%
## obtener el promedio de los valores
y_promedio=y_act.mean()*np.ones(n)
plt.plot(x, y_promedio)
