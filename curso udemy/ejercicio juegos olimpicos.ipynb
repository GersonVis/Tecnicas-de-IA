# %% [markdown]
# ## Ejercicio de juegos olimpicos

# %%
## joins datasets cruzar datos

# %%
## importaciones que vamos a ocupar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Joins

# %%
## creamos la ruta de los archivos a utilizar
file_path="athletes/"

# %%
## cargamos el primer dataset
medals=pd.read_csv(file_path+"Medals.csv", encoding="iso-8859-1")
medals.head(5)
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
## obtener solo una vez cada registro
medals["Athlete"].unique()
# Out:
# array(['Michael Phelps', 'Natalie Coughlin', 'Aleksey Nemov', ...,
#        'Wietse van Alten', 'Sandra Wagner-Sachse', 'Rod White'],
#       dtype=object)

# %%
## cargar datos por nacion
country=pd.read_csv(file_path+"Athelete_Country_Map.csv", encoding="iso-8859-1")
country
# Out:
#                    Athlete        Country
# 0           Michael Phelps  United States
# 1         Natalie Coughlin  United States
# 2            Aleksey Nemov         Russia
# 3            Alicia Coutts      Australia
# 4           Missy Franklin  United States
# ...                    ...            ...
# 6965      Olena Sadovnycha        Ukraine
# 6966      Kateryna Serdiuk        Ukraine
# 6967      Wietse van Alten    Netherlands
# 6968  Sandra Wagner-Sachse        Germany
# 6969             Rod White  United States
#
# [6970 rows x 2 columns]

# %%
medals.shape[0]
# Out:
# 8618

# %%
country.shape[0]
# Out:
# 6970

# %%
## importamos informacion de los deportes
sports=pd.read_csv(file_path+"Athelete_Sports_Map.csv", encoding="iso-8859-1")
sports
# Out:
#                    Athlete       Sport
# 0           Michael Phelps    Swimming
# 1         Natalie Coughlin    Swimming
# 2            Aleksey Nemov  Gymnastics
# 3            Alicia Coutts    Swimming
# 4           Missy Franklin    Swimming
# ...                    ...         ...
# 6970      Olena Sadovnycha     Archery
# 6971      Kateryna Serdiuk     Archery
# 6972      Wietse van Alten     Archery
# 6973  Sandra Wagner-Sachse     Archery
# 6974             Rod White     Archery
#
# [6975 rows x 2 columns]

# %%
len(sports)
medals.columns.values
# Out:
# array(['Athlete', 'Age', 'Year', 'Closing Ceremony Date', 'Gold Medals',
#        'Silver Medals', 'Bronze Medals', 'Total Medals'], dtype=object)

# %% [markdown]
# ## Merge

# %%
## especificar que datos quedaran a la izquierda y que datos quedaran a la derecha
## merge medallas y paises
medals_country=pd.merge(right=medals, left=country,
                        left_on="Athlete", right_on="Athlete")
medals_country.shape
# Out:
# (8657, 9)

# %%
## quitar los atletas duplicados por país
country_not_dp=country.drop_duplicates()
country_not_dp.shape
# Out:
# (6970, 2)

# %%
## unimos los dos datasets 
medals_country_not_dp=pd.merge(right=medals, left=country_not_dp,
                               right_on="Athlete", left_on="Athlete")
medals_country_not_dp.head(5)
# Out:
#             Athlete        Country   Age  Year Closing Ceremony Date  \
# 0    Michael Phelps  United States  23.0  2008            08/24/2008
# 1    Michael Phelps  United States  19.0  2004            08/29/2004
# 2    Michael Phelps  United States  27.0  2012            08/12/2012
# 3  Natalie Coughlin  United States  25.0  2008            08/24/2008
# 4  Natalie Coughlin  United States  21.0  2004            08/29/2004
#
#    Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0            8              0              0             8
# 1            6              0              2             8
# 2            4              2              0             6
# 3            1              2              3             6
# 4            2              2              1             5

# %%
## limpiar los datos del deporte que no estén duplicados los deportes por deportista
sports_not_dp=sports.drop_duplicates()

# %%
## unir deportes con la tabla medallas por país
medals_country_sports=pd.merge(left=medals_country_not_dp, right=sports_not_dp,
                               right_on="Athlete", left_on="Athlete")
medals_country_sports.head(5)
# Out:
#             Athlete        Country   Age  Year Closing Ceremony Date  \
# 0    Michael Phelps  United States  23.0  2008            08/24/2008
# 1    Michael Phelps  United States  19.0  2004            08/29/2004
# 2    Michael Phelps  United States  27.0  2012            08/12/2012
# 3  Natalie Coughlin  United States  25.0  2008            08/24/2008
# 4  Natalie Coughlin  United States  21.0  2004            08/29/2004
#
#    Gold Medals  Silver Medals  Bronze Medals  Total Medals     Sport
# 0            8              0              0             8  Swimming
# 1            6              0              2             8  Swimming
# 2            4              2              0             6  Swimming
# 3            1              2              3             6  Swimming
# 4            2              2              1             5  Swimming

# %%
print(medals.shape)
print(country_not_dp.shape)
# Out:
# (8618, 8)
# (6970, 2)

# %%
## pruebas de merge
dataA=pd.DataFrame({
    "nombre":["gerson", "jerman", "juan"],
    "nacionalidad": ["mexico", "usa", "puerto rico"],
    "deporte": ["futbol", "basquetbol", "boleivol"]
})

# %%
dataB=pd.DataFrame({
    "nombre": ["gerson", "jerman", "juan", "gerson"],
     "edad": [10, 32, 20, 90]
})

# %%
dataC=pd.DataFrame({
    "nombre": ["gerson", "jerman", "juan"],
    "color favorito": ["Azul","blanco", "rojo"] 
})

# %%
## hacer registros unidos un dataset
dataB=dataB["nombre"].drop_duplicates()
## merge para el dataA y el dataB
dataAB=pd.merge(right=dataA, left=dataB, right_on="nombre", left_on="nombre")

# %%
dataAB
# Out:
#    nombre nacionalidad     deporte
# 0  gerson       mexico      futbol
# 1  jerman          usa  basquetbol
# 2    juan  puerto rico    boleivol

# %%
dataB["nombre"].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Golfa\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\Golfa\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'nombre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7212/2362244038.py in <module>
# ----> 1 dataB["nombre"].drop_duplicates()
#
# ...

# %%
country.columns.values
# Out:
# array(['Athlete', 'Country'], dtype=object)

# %%
country["Contador"]=np.ones(country.shape[0])

# %%
country
# Out:
#                    Athlete        Country  Contador
# 0           Michael Phelps  United States       1.0
# 1         Natalie Coughlin  United States       1.0
# 2            Aleksey Nemov         Russia       1.0
# 3            Alicia Coutts      Australia       1.0
# 4           Missy Franklin  United States       1.0
# ...                    ...            ...       ...
# 6965      Olena Sadovnycha        Ukraine       1.0
# 6966      Kateryna Serdiuk        Ukraine       1.0
# 6967      Wietse van Alten    Netherlands       1.0
# 6968  Sandra Wagner-Sachse        Germany       1.0
# 6969             Rod White  United States       1.0
#
# [6970 rows x 3 columns]

# %%
repetidos=country.groupby(["Athlete"])
repetidos.filter(lambda x: x["Contador"].sum()!=1).groupby("Athlete").count()
# Out:
#                    Country  Contador
# Athlete
# Aleksandar Ciric         2         2
# Aleksandar apic         2         2
# Chen Jing                2         2
# David Musulbes           2         2
# Dejan Savic              2         2
# Denis efik              2         2
# Gyuzel Manyurova         2         2
# Iván García              2         2
# Matt Wells               2         2
# Richard Thompson         2         2
# Slobodan Nikic           2         2
# Vanja Udovicic           2         2
# Vlada Vujasinovic        2         2

# %%
subconjunto=country.loc[[2758, 3761, 5025, 6786, 1136, 1127], :]
subconjunto
# Out:
#                 Athlete                Country  Contador
# 2758         Matt Wells          Great Britain       1.0
# 3761         Matt Wells              Australia       1.0
# 5025        Iván García                 Mexico       1.0
# 6786        Iván García                   Cuba       1.0
# 1136  Vlada Vujasinovic  Serbia and Montenegro       1.0
# 1127        Denis efik  Serbia and Montenegro       1.0

# %%
subGrup=subconjunto.drop_duplicates(["Athlete"])
subGrup
# Out:
#                 Athlete                Country  Contador
# 2758         Matt Wells          Great Britain       1.0
# 5025        Iván García                 Mexico       1.0
# 1136  Vlada Vujasinovic  Serbia and Montenegro       1.0
# 1127        Denis efik  Serbia and Montenegro       1.0

# %%
subGrup.filter(lambda x: np.sum(x["Contador"])!=1).drop_duplicates(["Athlete"])
# Out:
#           Athlete        Country  Contador
# 2758   Matt Wells  Great Britain       1.0
# 5025  Iván García         Mexico       1.0

# %% [markdown]
# ## Cruzar tablas

# %%
country_not_dp=country_not_dp.drop_duplicates("Athlete")

# %%
## obtener 6 nombres aleatorios del dataset countrys
out_athletes=np.random.choice(country_not_dp["Athlete"], size=6, replace=False)
out_athletes
# Out:
# array(['Debbie Ferguson-McKenzie', 'Nastia Liukin', 'Tamari Miyashiro',
#        'Sheilla', 'Ruth Riley', "Michaël D'Almeida"], dtype=object)

# %%
dataframe_without = lambda dataFrame, out_items, column_name: ~dataFrame[column_name].isin(out_items)

# %%
country_not_athletes=country_not_dp[(dataframe_without(country_not_dp,out_athletes,"Athlete"))
                                    &(country_not_dp["Athlete"]!="Michael Phelps")]
country_not_athletes
# Out:
#                    Athlete        Country
# 1         Natalie Coughlin  United States
# 2            Aleksey Nemov         Russia
# 3            Alicia Coutts      Australia
# 4           Missy Franklin  United States
# 5              Ryan Lochte  United States
# ...                    ...            ...
# 6965      Olena Sadovnycha        Ukraine
# 6966      Kateryna Serdiuk        Ukraine
# 6967      Wietse van Alten    Netherlands
# 6968  Sandra Wagner-Sachse        Germany
# 6969             Rod White  United States
#
# [6949 rows x 2 columns]

# %%
medals_not_athletes=medals_country_not_dp[(dataframe_without(medals_country_not_dp,out_athletes,"Athlete"))
                                    &(medals_country_not_dp["Athlete"]!="Michael Phelps")]
medals_not_athletes
# Out:
#                    Athlete        Country   Age  Year Closing Ceremony Date  \
# 3         Natalie Coughlin  United States  25.0  2008            08/24/2008
# 4         Natalie Coughlin  United States  21.0  2004            08/29/2004
# 5         Natalie Coughlin  United States  29.0  2012            08/12/2012
# 6            Aleksey Nemov         Russia  24.0  2000            10/01/2000
# 7            Alicia Coutts      Australia  24.0  2012            08/12/2012
# ...                    ...            ...   ...   ...                   ...
# 8652      Olena Sadovnycha        Ukraine  32.0  2000            10/01/2000
# 8653      Kateryna Serdiuk        Ukraine  17.0  2000            10/01/2000
# 8654      Wietse van Alten    Netherlands  21.0  2000            10/01/2000
# 8655  Sandra Wagner-Sachse        Germany  31.0  2000            10/01/2000
# 8656             Rod White  United States  23.0  2000            10/01/2000
#
# ...

# %%
sports_not_athletes=sports_not_dp[(dataframe_without(sports_not_dp,out_athletes,"Athlete"))
                                    &(sports_not_dp["Athlete"]!="Michael Phelps")]
sports_not_athletes
# Out:
#                    Athlete       Sport
# 1         Natalie Coughlin    Swimming
# 2            Aleksey Nemov  Gymnastics
# 3            Alicia Coutts    Swimming
# 4           Missy Franklin    Swimming
# 5              Ryan Lochte    Swimming
# ...                    ...         ...
# 6970      Olena Sadovnycha     Archery
# 6971      Kateryna Serdiuk     Archery
# 6972      Wietse van Alten     Archery
# 6973  Sandra Wagner-Sachse     Archery
# 6974             Rod White     Archery
#
# [6968 rows x 2 columns]

# %% [markdown]
# ## ejemplo de joins con python

# %%
dataA=pd.DataFrame({
    "nombre":["gerson", "jerman", "juan", "pablo", "fernando"],
    "nacionalidad": ["mexico", "usa", "puerto rico", "mexico", "uruguay"],
    "deporte": ["futbol", "basquetbol", "boleivol", "basquet", "basquet"]
})

# %%
dataB=pd.DataFrame({
    "pais": ["usa", "mexico", "puerto rico", "venezuela", "francia"],
    "comida tipica": ["hamburguesa", "pozole", "palomas", "pechuga", "espagueti"]
})
dataB
# Out:
#           pais comida tipica
# 0          usa   hamburguesa
# 1       mexico        pozole
# 2  puerto rico       palomas
# 3    venezuela       pechuga
# 4      francia     espagueti

# %%
dataC=pd.DataFrame({
    "platillo": ["hamburguesa", "pozole", "palomas", "pechuga", "espagueti", "caldo de maricos"],
    "precio":  100+50*np.random.randn(6)
})

# %%
inner_join=pd.merge(left=dataA, right=dataB, left_on="nacionalidad", right_on="pais")
inner_join
# Out:
#    nombre nacionalidad     deporte         pais comida tipica
# 0  gerson       mexico      futbol       mexico        pozole
# 1   pablo       mexico     basquet       mexico        pozole
# 2  jerman          usa  basquetbol          usa   hamburguesa
# 3    juan  puerto rico    boleivol  puerto rico       palomas

# %%
inner_join=pd.merge(left=dataA, right=dataB, left_on="nacionalidad", right_on="pais", how="inner")
inner_join
# Out:
#    nombre nacionalidad     deporte         pais  habitantes
# 0  gerson       mexico      futbol       mexico   520632958
# 1   pablo       mexico     basquet       mexico   520632958
# 2  jerman          usa  basquetbol          usa     9382913
# 3    juan  puerto rico    boleivol  puerto rico    89528580

# %%
## hacer un left join tener los daos que no están en la interseccion de a y b
## personas sin nacionalidad
left_join=pd.merge(left=dataA, right=dataB, left_on="nacionalidad", right_on="pais", how="left")
left_join[pd.isna(left_join["pais"])]
# Out:
#      nombre nacionalidad  deporte pais comida tipica
# 4  fernando      uruguay  basquet  NaN           NaN

# %%
right_join=pd.merge(left=dataA, right=dataB, left_on="nacionalidad", right_on="pais", how="right")
right_join
# Out:
#    nombre nacionalidad     deporte         pais comida tipica
# 0  jerman          usa  basquetbol          usa   hamburguesa
# 1  gerson       mexico      futbol       mexico        pozole
# 2   pablo       mexico     basquet       mexico        pozole
# 3    juan  puerto rico    boleivol  puerto rico       palomas
# 4     NaN          NaN         NaN    venezuela       pechuga
# 5     NaN          NaN         NaN      francia     espagueti

# %%
## añadir un registro
dataB.append({
    "pais": "cuba",
    "comida tipica": "arroz"
    }, ignore_index=True
    )
# Out:
#           pais comida tipica
# 0          usa   hamburguesa
# 1       mexico        pozole
# 2  puerto rico       palomas
# 3    venezuela       pechuga
# 4      francia     espagueti
# 5         cuba         arroz

# %%
## outer todo de todo
outer_join=pd.merge(left=dataA, right=dataB, left_on="nacionalidad", right_on="pais", how="outer")
outer_join[(pd.isna(outer_join["nombre"]))]
# Out:
#   nombre nacionalidad deporte       pais comida tipica
# 5    NaN          NaN     NaN  venezuela       pechuga
# 6    NaN          NaN     NaN    francia     espagueti

# %%
np.isnan(np.nan)
# Out:
# True
